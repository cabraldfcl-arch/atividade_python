# %% [markdown]
# ####exemplo and

# %%
idade_pessoa = int(input("Digite a sua idade:"))
estudante = input("É estudante? (s/n)")

if idade_pessoa >= 12 and estudante == 's':
    print('Entrada permitida!')
else:
    print('Não pode entrar!')
# Out:
# Digite a sua idade: 18
# É estudante? (s/n) s
# Entrada permitida!

# %% [markdown]
# ####exemplo or

# %%
idade_pessoa = int(input("Digite a sua idade:"))
estudante = input("É estudante? (s/n)")

if idade_pessoa >= 12 or estudante == 's':
    print('Entrada permitida!')
else:
    print('Não pode entrar!')
# Out:
# Digite a sua idade: 12
# É estudante? (s/n) s
# Entrada permitida!

# %% [markdown]
# Exemplo com Not

# %%
senha_correta = True
if not senha_correta:
    pritn("Senha incorreta!")
else:
    print("Senha Correta!")
# Out:
# Senha Correta!
