# %% [markdown]
# Atividade 1

# %%
print("Eu estou apredendo Python")
# Out:
# Eu estou apredendo Python

# %% [markdown]
# Atividade 2

# %%
print("Meu nome é Ana Maria")
print("Eu moro no goias")
# Out:
# Meu nome é Ana Maria
# Eu moro no goias

# %% [markdown]
# Atividade 3

# %%
nome_aluno = input("Escreva seu nome: ")
idade_aluno = input("Escreva sua idade")
print("Meu nome é " + nome_aluno + " Minha idade é " + idade_aluno)
# Out:
# Escreva seu nome:  diego
# Escreva sua idade 38
# Meu nome é diego Minha idade é 38

# %% [markdown]
# Atividade 4

# %%
cidade = "Salvador"
estado = "BA"
pais = "Brasil"

print("Eu moro em " + cidade + "-" + estado + ", " + pais)
# Out:
# Eu moro em Salvador-BA, Brasil

# %% [markdown]
# Atividade 5
